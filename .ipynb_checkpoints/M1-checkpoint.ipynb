# %% [markdown]
# # DataPreprocessing

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data = pd.read_json('intents.json')

# %%
data.head()
# Out:
#                                              intents
# 0  [{'tag': 'job_seeker_greeting', 'patterns': ['...

# %%
data.shape
# Out:
# (1, 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   intents  1 non-null      object
# dtypes: object(1)
# memory usage: 136.0+ bytes

# %%
df = data.dropna()

# %%
df.isnull().sum()
# Out:
# intents    0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of                                              intents
# 0  [{'tag': 'job_seeker_greeting', 'patterns': ['...>

# %%
df.columns
# Out:
# Index(['intents'], dtype='object')

# %%
df.size
# Out:
# 1

# %%
df.describe()
# Out:
#                                                   intents
# count                                                   1
# unique                                                  1
# top     [{'tag': 'job_seeker_greeting', 'patterns': ['...
# freq                                                    1

# %%
df.head()
# Out:
#                                              intents
# 0  [{'tag': 'job_seeker_greeting', 'patterns': ['...

# %%
df.head()
# Out:
#                                              intents
# 0  [{'tag': 'job_seeker_greeting', 'patterns': ['...

# %%
import ydata_profiling as yp
import pandas_profiling
from pandas_profiling import ProfileReport
from ydata_profiling.model import describe
prof = ProfileReport(df)
prof.to_file(output_file='Report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
